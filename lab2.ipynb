# %%
import sys, os
sys.path.append(os.path.abspath("src"))

# %%
from src.BST import BST
from src.AVL import AVL
from src.RBT import RBT

# %%
from src.tests import test_bst, test_avl, test_rbt

test_bst()
test_avl()
test_rbt()
# Out:
# ===================== BST ДЕРЕВО =====================
#
# Дерево:
# Root: 45 h:2
# L--- 20 h:1
#      L--- 10 h:0
#      R--- 30 h:0
# R--- 70 h:1
#      L--- 60 h:0
#      R--- 90 h:0
#
# Прямой обход: [45, 20, 10, 30, 70, 60, 90]
# Центрированный обход: [10, 20, 30, 45, 60, 70, 90]
# Обратный обход: [10, 30, 20, 60, 90, 70, 45]
# Обход в ширину: [45, 20, 70, 10, 30, 60, 90]
# Обход в глубину: [45, 20, 10, 30, 70, 60, 90]
#
# Минимум: 10 , Максимум: 90
#
# Поиск 30: Найден
#
# После удаления 20:
# Root: 45 h:2
# L--- 30 h:1
#      L--- 10 h:0
# R--- 70 h:1
#      L--- 60 h:0
#      R--- 90 h:0
#
# ===================== AVL ДЕРЕВО =====================
#
# AVL дерево после вставки:
# Высота дерева: 3
# Root: 25 (h:3, b:0)
# L--- 15 (h:2, b:0)
#      L--- 10 (h:1, b:0)
#           L--- 5 (h:0, b:0)
#           R--- 12 (h:0, b:0)
#      R--- 18 (h:1, b:-1)
#           R--- 20 (h:0, b:0)
# R--- 40 (h:2, b:0)
#      L--- 30 (h:1, b:-1)
#           R--- 35 (h:0, b:0)
# ...

# %%
from src.experiments import (
    bst_random_heights,
    avl_rbt_random_heights,
    avl_rbt_sorted_heights
)

bst_random_heights()
avl_rbt_random_heights()
avl_rbt_sorted_heights()
